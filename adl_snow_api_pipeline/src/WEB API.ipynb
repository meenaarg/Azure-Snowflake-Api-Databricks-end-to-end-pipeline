# %%
##URL data read

import urllib.request
from pyspark.sql.functions import *

url = "https://randomuser.me/api/0.8/?results=100"

urldata = urllib.request.urlopen(url).read().decode("utf-8")

schema = spark.range(1).select(schema_of_json(lit(urldata))).first()[0]

jsondf = spark.createDataFrame([(urldata,)], ["json_data"]) \
              .select(from_json(col("json_data"), schema).alias("data")) \
              .select("data.*")

jsondf.printSchema()

final_df = jsondf.withColumn("results", explode("results")).selectExpr(
    "nationality",
    "results.user.gender as gender",
    "results.user.name.title as title",
    "results.user.name.first as first",
    "results.user.name.last as last",
    "results.user.location.street as street",
    "results.user.location.city as city",
    "results.user.location.state as state",
    "results.user.location.zip as zip",
    "results.user.email as email",
    "results.user.username as username",
    "results.user.password as password",
    "results.user.salt as salt",
    "results.user.md5 as md5",
    "results.user.sha1 as sha1",
    "results.user.sha256 as sha256",
    "results.user.registered as registered",
    "results.user.dob as dob",
    "results.user.phone as phone",
    "results.user.cell as cell",
    "results.user.picture.large as large",
    "results.user.picture.medium as medium",
    "results.user.picture.thumbnail as thumbnail",
    "seed",
    "version"
)

final_df.display()
final_df.printSchema()
# Out:
# root
#  |-- nationality: string (nullable = true)
#  |-- results: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- SSN: string (nullable = true)
#  |    |    |    |-- cell: string (nullable = true)
#  |    |    |    |-- dob: long (nullable = true)
#  |    |    |    |-- email: string (nullable = true)
#  |    |    |    |-- gender: string (nullable = true)
#  |    |    |    |-- location: struct (nullable = true)
#  |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |-- street: string (nullable = true)
#  |    |    |    |    |-- zip: long (nullable = true)
#  |    |    |    |-- md5: string (nullable = true)
#  |    |    |    |-- name: struct (nullable = true)
#  |    |    |    |    |-- first: string (nullable = true)
#  |    |    |    |    |-- last: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- password: string (nullable = true)
#  |    |    |    |-- phone: string (nullable = true)
#  |    |    |    |-- picture: struct (nullable = true)
#  |    |    |    |    |-- large: string (nullable = true)
#  |    |    |    |    |-- medium: string (nullable = true)
#  |    |    |    |    |-- thumbnail: string (nullable = true)
#  |    |    |    |-- registered: long (nullable = true)
#  |    |    |    |-- salt: string (nullable = true)
#  |    |    |    |-- sha1: string (nullable = true)
#  |    |    |    |-- sha256: string (nullable = true)
#  |    |    |    |-- username: string (nullable = true)
#  |-- seed: string (nullable = true)
#  |-- version: string (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nationality</th><th>gender</th><th>title</th><th>first</th><th>last</th><th>street</th><th>city</th><th>state</th><th>zip</th><th>email</th><th>username</th><th>password</th><th>salt</th><th>md5</th><th>sha1</th><th>sha256</th><th>registered</th><th>dob</th><th>phone</th><th>cell</th><th>large</th><th>medium</th><th>thumbnail</th><th>seed</th><th>version</th></tr></thead><tbody><tr><td>US</td><td>female</td><td>mrs</td><td>catherine</td><td>griffin</td><td>5748 washington ave</td><td>oxnard</td><td>wisconsin</td><td>39591</td><td>catherine.griffin@example.com</td><td>beautifulgoose523</td><td>savior</td><td>DruCgFV0</td><td>d1e83f0ca2a764438b84e185d689d598</td><td>30cd78b0f4e1d91d74fc88b19b5a697749696713</td><td>e96835bdb52315a64946c44c258c8c503cec5676f4dd2703e2dd67194fe05697</td><td>1364224243</td><td>816670737</td><td>(450
# root
#  |-- nationality: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- first: string (nullable = true)
#  |-- last: string (nullable = true)
#  |-- street: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- zip: long (nullable = true)
#  |-- email: string (nullable = true)
#  |-- username: string (nullable = true)
#  |-- password: string (nullable = true)
#  |-- salt: string (nullable = true)
#  |-- md5: string (nullable = true)
#  |-- sha1: string (nullable = true)
#  |-- sha256: string (nullable = true)
#  |-- registered: long (nullable = true)
#  |-- dob: long (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- cell: string (nullable = true)
#  |-- large: string (nullable = true)
#  |-- medium: string (nullable = true)
#  |-- thumbnail: string (nullable = true)
#  |-- seed: string (nullable = true)
#  |-- version: string (nullable = true)

# %%
##Removing numbers from username column

from pyspark.sql.functions import *

removenum = final_df.withColumn("username",expr("regexp_replace(username,'[0-9]', '')"))
removenum.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nationality</th><th>gender</th><th>title</th><th>first</th><th>last</th><th>street</th><th>city</th><th>state</th><th>zip</th><th>email</th><th>username</th><th>password</th><th>salt</th><th>md5</th><th>sha1</th><th>sha256</th><th>registered</th><th>dob</th><th>phone</th><th>cell</th><th>large</th><th>medium</th><th>thumbnail</th><th>seed</th><th>version</th></tr></thead><tbody><tr><td>IR</td><td>male</td><td>mr</td><td>رضا</td><td>صدر</td><td>7625 آذربایجان</td><td>ملارد</td><td>همدان</td><td>62488</td><td>رضا.صدر@example.com</td><td>lazyduck</td><td>abcdefg</td><td>AiPLbHcp</td><td>437fb05a8a04124919a2b7d6c1c32098</td><td>88c8edd648330be77b5ef3f3cab9b701bc8bca7e</td><td>fb004209aaba09161a118a231e0ed5167bbabe3e09ca12abe8cac0dcce2211f3</td><td>1411080620</td><td>417331412</td><td>031-07296694</td><td>0946-559-2331</td><td>https://randomuser.me/api/portraits/men/51.jpg</td><td>https://randomuser.me/api/portraits/med/men/51.jpg</td><td>https://randomuser.me/api/portraits/thumb/men/51.jpg</td><td>d17fcd9c6f7fbaf70a</td><td>0.8</td></tr><tr><td>IR</td><td>female</td><td>ms</td><td>تارا</td><td>کریمی</td><td>6405 میدان صادقیه</td><td>کرج</td><td>فارس</td><td>99204</td><td>تارا.کریمی@example.com</td><td>orangefish</td><td>dynamite</td><td>rYtcKZXz</td><td>e9c3e866fb68881099ec1c18b8181212</td><td>7b76bfda2b61bcd67f413153cf93e8cce1dabdc8</td><td>d7d237858ae131f54c76f2daf80a618fe0be1af5860e215cfc124d513b934d71</td><td>1226216875</td><td>1186996025</td><td>088-50873094</td><td>0930-796-3788</td><td>https://randomuser.me/api/portraits/women/51.jpg</td><td>https://randomuser.me/api/portraits/med/women/51.jpg</td><td>https://randomuser.me/api/portraits/thumb/women/51.jpg</td><td>d17fcd9c6f7fbaf70a</td><td>0.8</td></tr><tr><td>IR</td><td>male</td><td>mr</td><td>حسین</td><td>رضاییان</td><td>9702 نبرد</td><td>بجنورد</td><td>خراسان جنوبی</td><td>67429</td><td>حسین.رضاییان@example.com</td><td>crazysnake</td><td>yellow1</td><td>37WlontC</td><td>5df8a28e1a25b9055e0f619254402928</td><td>2ef978117a5992154367dca55f46ba3fea720006</td><td>ee96706252d5f